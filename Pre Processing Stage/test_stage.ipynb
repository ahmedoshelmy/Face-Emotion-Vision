# %%
import main
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
main.process("images")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 main.process("images")
#
# File c:\Users\ASUS\Documents\GitHub\Face-Emotion-Vision\Pre Processing Stage\main.py:24, in process(folder, rem_noise, gamma_correction, hist_equalization)
#      22 commonfunctions.show_images(images, ["Median Filter"])
#      23 # Apply gamma correction
# ---> 24 images = [gamma_correction(img, 0.5) for img in images]
#      25 # Show the images after applying gamma correction
#      26 commonfunctions.show_images(images, ["Gamma Correction"])
#
# File c:\Users\ASUS\Documents\GitHub\Face-Emotion-Vision\Pre Processing Stage\main.py:24, in <listcomp>(.0)
#      22 commonfunctions.show_images(images, ["Median Filter"])
#      23 # Apply gamma correction
# ---> 24 images = [gamma_correction(img, 0.5) for img in images]
# ...
