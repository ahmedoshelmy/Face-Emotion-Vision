# %%
import main
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
main.process("meimages", edge_det=True)
main.process("meimages", gamma_corre=True, hist_eq=True, edge_det=True, edge_det_method="sobel")
# Out:
# [array([[0.00143796, 0.00160337, 0.00506183, ..., 0.03005684, 0.00893002,
#          0.0074608 ],
#         [0.00551533, 0.00441622, 0.00384528, ..., 0.05005185, 0.01745762,
#          0.01608178],
#         [0.00751355, 0.00568003, 0.0018779 , ..., 0.06382474, 0.03386302,
#          0.01411518],
#         ...,
#         [0.00877785, 0.00748675, 0.00595281, ..., 0.023055  , 0.02911558,
#          0.01248095],
#         [0.00485038, 0.00396046, 0.00237774, ..., 0.02310299, 0.03200872,
#          0.02367652],
#         [0.00231091, 0.0017145 , 0.00102766, ..., 0.01753354, 0.02741822,
#          0.01724394]]),
#  array([[1.00609747e-02, 1.89613898e-02, 1.06477598e-02, ...,
#          5.37050709e-03, 3.13435295e-03, 1.96261557e-17],
#         [1.38645281e-02, 2.01647669e-02, 2.10073880e-02, ...,
#          4.25733763e-03, 3.52992256e-03, 1.96261557e-17],
#         [2.23336680e-02, 2.22374493e-02, 2.02383825e-02, ...,
#          3.68607309e-03, 3.52282872e-03, 1.96261557e-17],
# ...
