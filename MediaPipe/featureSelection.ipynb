# %%
import sys
sys.path.insert(1, '../')

from  commonfunctions import *
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import sys
#       2 sys.path.insert(1, '../')
# ----> 4 from  commonfunctions import *
#
# File d:\GitHub Repos\Face-Emotion-Vision\MediaPipe\..\commonfunctions.py:3
# ----> 3 import mediapipe as mp
#       4 from mediapipe.framework.formats import landmark_pb2
#       5 from mediapipe import solutions
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\mediapipe\__init__.py:17
#      15 from mediapipe.python import *
#      16 import mediapipe.python.solutions as solutions
# ---> 17 import mediapipe.tasks.python as tasks
#      20 del framework
#      21 del gpu
#
# File c:\Users\lenovo\AppData\Local\Programs\Python\Python311\Lib\site-packages\mediapipe\tasks\python\__init__.py:21
#      19 from . import core
#      20 from . import text
# ---> 21 from . import vision
# ...

# %%
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import cv2

# %%
base_options = python.BaseOptions(model_asset_path='./face_landmarker.task')
options = vision.FaceLandmarkerOptions(base_options=base_options,
                                       output_face_blendshapes=True,
                                       output_facial_transformation_matrixes=True,
                                       num_faces=1)
detector = vision.FaceLandmarker.create_from_options(options)

def detect(path):
    image = mp.Image.create_from_file(path)

    detection_result = detector.detect(image)

    annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)
    return annotated_image , detection_result

# %%
path = '../Data/Student-engagement-dataset/Engaged/frustrated/0032.jpg'
image , result = detect(path)
show_images([image, cv2.imread(
    path)])
plot_face_blendshapes_bar_graph(result.face_blendshapes[0])

# %%
path = '../Data/Student-engagement-dataset/Engaged/engaged/0063.jpg'
image, result = detect(path)
show_images([image, cv2.imread(
    path)])
plot_face_blendshapes_bar_graph(result.face_blendshapes[0])

# %%
path = '../Data/Student-engagement-dataset/Engaged/confused/0035.jpg'
image, result = detect(path)
show_images([image, cv2.imread(
    path)])
plot_face_blendshapes_bar_graph(result.face_blendshapes[0])

# %%
path = '../Data/Student-engagement-dataset/Not engaged/bored/0022.jpg'
image, result = detect(path)
show_images([image, cv2.imread(
    path)])
plot_face_blendshapes_bar_graph(result.face_blendshapes[0])

# %%
path = '../Data/Student-engagement-dataset/Not engaged/drowsy/0022.jpg'
image, result = detect(path)
show_images([image, cv2.imread(
    path)])
plot_face_blendshapes_bar_graph(result.face_blendshapes[0])

# %%
path = '../Data/Student-engagement-dataset/Not engaged/Looking Away/0037.jpg'
image, result = detect(path)
show_images([image, cv2.imread(
    path)])
plot_face_blendshapes_bar_graph(result.face_blendshapes[0])
